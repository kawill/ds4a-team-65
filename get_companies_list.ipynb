# %%
import pandas as pd

# %%
df = pd.read_csv('S&P500-Info_Twitter_link.csv', index_col=0)

# %%
df.head()
# Out:
#   symbol             security sec filings             gics sector  \
# 0    MMM           3M Company     reports             Industrials
# 1    ABT  Abbott Laboratories     reports             Health Care
# 2   ABBV          AbbVie Inc.     reports             Health Care
# 3   ABMD          ABIOMED Inc     reports             Health Care
# 4    ACN        Accenture plc     reports  Information Technology
#
#                 gics sub-industry    headquarters location date first added  \
# 0        Industrial Conglomerates      St. Paul, Minnesota         8/9/1976
# 1           Health Care Equipment  North Chicago, Illinois        3/31/1964
# 2                 Pharmaceuticals  North Chicago, Illinois       12/31/2012
# 3           Health Care Equipment   Danvers, Massachusetts        5/31/2018
# 4  IT Consulting & Other Services          Dublin, Ireland         7/6/2011
#
#        cik      founded  twitter handle
# 0    66740         1902          3mnews
# ...

# %%
df = df[df['twitter handle'].notna()]

# %%
handlers_lst = df[['twitter handle']]

# %%
handlers_lst.to_json('handlers.json')

# %%
df['twitter handle'].tolist()
# Out:
# ['3mnews',
#  'abbottglobal',
#  'abbvieus',
#  'abiomedimpella',
#  'accenture',
#  'atvi_ab',
#  'adobe',
#  'amd',
#  'advanceauto',
#  'theaescorp',
#  'aflac',
#  'agilent',
#  'airproducts',
#  'akami',
#  'alaskaair',
#  'albemarlecorp',
#  'alexionpharma',
#  'aligntechinc',
#  'allegionplc',
#  'alliantenergyia',
#  'allstate',
#  'alphabetinc',
#  'google',
#  'altrianews',
#  'amazon',
#  'amcorpackaging',
#  'amerencorp',
#  'americanair',
#  'aepnews',
#  'americanexpress',
#  'aiginsurance',
#  'americantowerus',
#  'amwater',
#  'ameriprise',
#  'healthcare_abc',
#  'ametekinc',
#  'amgen',
#  'amphenol',
#  'adi_news',
#  'ansys',
#  'antheminc',
#  'aon_plc',
#  'aosmithhotwater',
#  'apachecorp',
#  'aimcoapts',
#  'apple',
#  'applied_blog',
#  'aptiv',
#  'admcares',
#  'aristanetworks',
#  'gallagherglobal',
#  'assurant',
#  'att',
#  'atmosenergy',
#  'autodesk',
#  'adp',
#  'autozone',
#  'avalonbay',
#  'avery dennison',
#  'bakerhughesco',
#  'ballcorphq',
# ...
